# %% [markdown]
# # ***Python para Traders*** - Banco Modal
#
# ### Camila Teixeira

# %% [markdown]
# ### Nesse código iremos aplicar os principais indicadores de análise técnica com Python através das bibliotecas:
# - Plotly - biblioteca para visualização de gráficos dinâmicos
# - TALib - biblioteca que calcula os indicadores de análise técnica em um frammework amigável para programadores
# - Investpy - captura de dados tratados de preço de abertura, fechamento, máxima, mímina e volume do mercado financeiro via API encapsulada em funções.

# %% [markdown]
# ## 1. Instalando Bibliotecas
#
# O comando !pip install instala as bibliotecas e todas suas dependências

# %%
# !pip install ta
# !pip install investpy
# !pip install plotly==5.9.0
# Out:
# Requirement already satisfied: ta in c:\users\camil\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\camil\anaconda3\lib\site-packages (from ta) (1.23.0)
# Requirement already satisfied: pandas in c:\users\camil\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\camil\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\camil\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\camil\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# Requirement already satisfied: investpy in c:\users\camil\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (4.6.3)
# Requirement already satisfied: Unidecode>=1.1.1 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (1.2.0)
# Requirement already satisfied: setuptools>=41.2.0 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (58.0.4)
# Requirement already satisfied: pytz>=2019.3 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (2021.3)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (1.23.0)
# Requirement already satisfied: requests>=2.22.0 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (2.26.0)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\camil\anaconda3\lib\site-packages (from investpy) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\camil\anaconda3\lib\site-packages (from pandas>=0.25.1->investpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\camil\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\camil\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\camil\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camil\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2021.10.8)
# Collecting plotly==5.9.0
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\camil\anaconda3\lib\site-packages (from plotly==5.9.0) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.8.0
#     Uninstalling plotly-5.8.0:
#       Successfully uninstalled plotly-5.8.0
# Successfully installed plotly-5.9.0

# %%
# !pip install "jupyterlab>=3" "ipywidgets>=7.6"
# !pip install jupyter-dash
# !pip install "notebook>=5.3" "ipywidgets>=7.5"
# Out:
# Requirement already satisfied: jupyterlab>=3 in c:\users\camil\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: ipywidgets>=7.6 in c:\users\camil\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: jinja2>=2.1 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (2.11.3)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (6.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (2.8.2)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (1.4.1)
# Requirement already satisfied: packaging in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (21.0)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (0.2.6)
# Requirement already satisfied: ipython in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (7.29.0)
# Requirement already satisfied: jupyter-core in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab>=3) (4.8.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.6) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.18.0)
# Requirement already satisfied: pygments in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (2.10.0)
# Requirement already satisfied: decorator in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (58.0.4)
# Requirement already satisfied: colorama in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.4.4)
# Requirement already satisfied: backcall in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\camil\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\camil\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab>=3) (2.1.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-core->jupyterlab>=3) (228)
# Requirement already satisfied: nbconvert in c:\users\camil\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\camil\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.11.0)
# Requirement already satisfied: anyio>=2.0.2 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (2.2.0)
# Requirement already satisfied: Send2Trash in c:\users\camil\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\camil\anaconda3\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\camil\anaconda3\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (3.2)
# Requirement already satisfied: babel in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.9.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (0.3)
# Requirement already satisfied: requests in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.26.0)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (3.2.0)
# Requirement already satisfied: json5 in c:\users\camil\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (0.9.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (0.18.0)
# Requirement already satisfied: notebook<7 in c:\users\camil\anaconda3\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3) (6.4.5)
# Requirement already satisfied: argon2-cffi in c:\users\camil\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=3) (20.1.0)
# Requirement already satisfied: wcwidth in c:\users\camil\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\camil\anaconda3\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\camil\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (2.20)
# Requirement already satisfied: pytz>=2015.7 in c:\users\camil\anaconda3\lib\site-packages (from babel->jupyterlab-server~=2.3->jupyterlab>=3) (2021.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.1.2)
# Requirement already satisfied: bleach in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.8.4)
# Requirement already satisfied: testpath in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.7.1)
# Requirement already satisfied: async-generator in c:\users\camil\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\camil\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\camil\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\camil\anaconda3\lib\site-packages (from packaging->jupyterlab>=3) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (2021.10.8)
# Requirement already satisfied: jupyter-dash in c:\users\camil\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ipython in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (7.29.0)
# Requirement already satisfied: retrying in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: dash in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (2.5.1)
# Requirement already satisfied: flask in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: ipykernel in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (6.4.1)
# Requirement already satisfied: ansi2html in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: requests in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (2.26.0)
# Requirement already satisfied: nest-asyncio in c:\users\camil\anaconda3\lib\site-packages (from jupyter-dash) (1.5.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\camil\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.9.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\camil\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: flask-compress in c:\users\camil\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.12)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\camil\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.2)
# Requirement already satisfied: click>=5.1 in c:\users\camil\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\camil\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\camil\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: colorama in c:\users\camil\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter-dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\camil\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (2.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\camil\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\camil\anaconda3\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.1.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (58.0.4)
# Requirement already satisfied: decorator in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: pygments in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.10.0)
# Requirement already satisfied: backcall in c:\users\camil\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\camil\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash) (228)
# Requirement already satisfied: wcwidth in c:\users\camil\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\camil\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter-dash) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: notebook>=5.3 in c:\users\camil\anaconda3\lib\site-packages (6.4.5)
# Requirement already satisfied: ipywidgets>=7.5 in c:\users\camil\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (6.1.0)
# Requirement already satisfied: jinja2 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (2.11.3)
# Requirement already satisfied: ipython-genutils in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (22.2.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (6.1.12)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (5.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (6.1)
# Requirement already satisfied: nbformat in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (5.1.3)
# Requirement already satisfied: prometheus-client in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (0.11.0)
# Requirement already satisfied: ipykernel in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (6.4.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\camil\anaconda3\lib\site-packages (from notebook>=5.3) (4.8.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.5) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.5) (7.29.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\camil\anaconda3\lib\site-packages (from ipywidgets>=7.5) (3.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\camil\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.7.5)
# Requirement already satisfied: pygments in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (58.0.4)
# Requirement already satisfied: backcall in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.2.0)
# Requirement already satisfied: decorator in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (3.0.20)
# Requirement already satisfied: colorama in c:\users\camil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\camil\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.3) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\camil\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.3) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\camil\anaconda3\lib\site-packages (from nbformat->notebook>=5.3) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.3) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.3) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\camil\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.3) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\camil\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\camil\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.3) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\camil\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.3) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\camil\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=5.3) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\camil\anaconda3\lib\site-packages (from jinja2->notebook>=5.3) (2.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.5.3)
# Requirement already satisfied: testpath in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.7.1)
# Requirement already satisfied: bleach in c:\users\camil\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (4.0.0)
# Requirement already satisfied: async-generator in c:\users\camil\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.3) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\camil\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.3) (1.5.1)
# Requirement already satisfied: packaging in c:\users\camil\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=5.3) (21.0)
# Requirement already satisfied: webencodings in c:\users\camil\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=5.3) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\camil\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=5.3) (3.0.4)

# %% [markdown]
# ## 2. Importando bibliotecas
#
# Importaremos também dois submódulos da biblioteca Plotly:
# - graph objects para construção dos gráficos dinâmicos e
# - make_subplots para quando precisarmos utilizar dois gráficos na mesma figura.

# %%
import ta
import investpy
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

import plotly.express as px

# %% [markdown]
# ## 3. Capturando Dados
#
# Iremos capturar os dados através da biblioteca investpy e traremos 3 ações diferentes para observarmos diferentes comportamentos dos indicadores

# %%
#DF 1 - BRMalls

df = investpy.get_stock_historical_data(stock='BRML3', country='Brazil', from_date='01/01/2019', to_date='30/03/2021')

# %%
df
# Out:
#              Open   High    Low  Close    Volume Currency
# Date
# 2019-01-02  12.22  12.63  12.12  12.59  14193800      BRL
# 2019-01-03  12.48  12.68  12.36  12.67   9265200      BRL
# 2019-01-04  12.55  12.71  12.43  12.43  11161000      BRL
# 2019-01-07  12.31  12.44  12.14  12.35   4569500      BRL
# 2019-01-08  12.40  12.44  12.25  12.37   4509200      BRL
# ...           ...    ...    ...    ...       ...      ...
# 2021-03-24   9.77  10.10   9.68   9.74  26928000      BRL
# 2021-03-25   9.71   9.95   9.48   9.82  23246700      BRL
# 2021-03-26   9.90   9.93   9.60   9.81  11872500      BRL
# 2021-03-29   9.71   9.91   9.65   9.74   7898800      BRL
# 2021-03-30   9.64  10.32   9.64  10.23  15812600      BRL
#
# [556 rows x 6 columns]

# %%
#DF2 - Petrobrás

df2 = investpy.get_stock_historical_data(stock='PETR4', country='Brazil', from_date='01/01/2019', to_date='30/03/2021')

df2
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2019-01-02  21.83  23.42  21.57  23.29  104534800      BRL
# 2019-01-03  23.55  24.02  23.04  23.86   95206400      BRL
# 2019-01-04  24.05  24.14  23.69  23.93   72119800      BRL
# 2019-01-07  24.05  25.09  23.91  24.30  121711904      BRL
# 2019-01-08  24.59  24.61  23.98  24.16   68761800      BRL
# ...           ...    ...    ...    ...        ...      ...
# 2021-03-24  23.19  23.54  22.82  22.82   62209500      BRL
# 2021-03-25  22.70  23.30  22.16  23.20   78839800      BRL
# 2021-03-26  23.48  23.88  23.11  23.46   60631800      BRL
# 2021-03-29  23.34  23.83  23.28  23.83   49670900      BRL
# 2021-03-30  23.64  23.99  23.57  23.83   40703300      BRL
#
# [556 rows x 6 columns]

# %%
#DF3 - WEG Industries

df3 = investpy.get_stock_historical_data(stock='WEGE3', country='Brazil', from_date='01/01/2019', to_date='30/03/2021')

df3
# Out:
#              Open   High    Low  Close    Volume Currency
# Date
# 2019-01-02   8.52   8.79   8.46   8.69   4751200      BRL
# 2019-01-03   8.73   8.89   8.56   8.89   8316400      BRL
# 2019-01-04   8.90   9.03   8.70   8.99   8340200      BRL
# 2019-01-07   9.07   9.07   8.80   8.85   5860200      BRL
# 2019-01-08   8.88   8.91   8.72   8.78   6306800      BRL
# ...           ...    ...    ...    ...       ...      ...
# 2021-03-24  35.70  36.28  34.94  35.07  16129600      BRL
# 2021-03-25  35.07  35.57  34.72  35.34  11509400      BRL
# 2021-03-26  35.40  36.58  35.30  36.17  11053600      BRL
# 2021-03-29  35.92  36.22  35.48  35.87   9793200      BRL
# 2021-03-30  35.69  37.53  35.58  37.34  12421800      BRL
#
# [556 rows x 6 columns]

# %% [markdown]
# ## 4. Estrutura de programação da Plotly

# %% [markdown]
# ### 4.1. Gráficos  de linhas

# %%
# Criar a figura
fig = go.Figure()

# Cria o gráfico de linhas
fig.add_trace(go.Scatter(name='PETR4', x=df2.index, y=df2['Close']))

# Alterar layout
fig.update_layout(title_text='Gráfico de Linhas',template = 'simple_white')
fig.show()
# Out:
# <div>                            <div id="6114b8c2-9a65-4d9e-b0bb-fca668bffd95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6114b8c2-9a65-4d9e-b0bb-fca668bffd95")) {                    Plotly.newPlot(                        "6114b8c2-9a65-4d9e-b0bb-fca668bffd95",                        [{"name":"PETR4","x":["2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-27T00:00:00","2019-05-28T00:00:00","2019-05-29T00:00:00","2019-05-30T00:00:00","2019-05-31T00:00:00","2019-06-03T00:00:00","2019-06-04T00:00:00","2019-06-05T00:00:00","2019-06-06T00:00:00","2019-06-07T00:00:00","2019-06-10T00:00:00","2019-06-11T00:00:00","2019-06-12T00:00:00","2019-06-13T00:00:00","2019-06-14T00:00:00","2019-06-17T00:00:00","2019-06-18T00:00:00","2019-06-19T00:00:00","2019-06-21T00:00:00","2019-06-24T00:00:00","2019-06-25T00:00:00","2019-06-26T00:00:00","2019-06-27T00:00:00","2019-06-28T00:00:00","2019-07-01T00:00:00","2019-07-02T00:00:00","2019-07-03T00:00:00","2019-07-04T00:00:00","2019-07-05T00:00:00","2019-07-08T00:00:00","2019-07-10T00:00:00","2019-07-11T00:00:00","2019-07-12T00:00:00","2019-07-15T00:00:00","2019-07-16T00:00:00","2019-07-17T00:00:00","2019-07-18T00:00:00","2019-07-19T00:00:00","2019-07-22T00:00:00","2019-07-23T00:00:00","2019-07-24T00:00:00","2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-12T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-15T00:00:00","2019-08-16T00:00:00","2019-08-19T00:0 ...

# %% [markdown]
# ### 4.2. Gráfico de candlestick

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high = df['High'], low=df['Low']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='Gráfico de Candlestick')
fig.show()
# Out:
# <div>                            <div id="790a5c28-17a1-43f1-a372-34862ee749ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("790a5c28-17a1-43f1-a372-34862ee749ce")) {                    Plotly.newPlot(                        "790a5c28-17a1-43f1-a372-34862ee749ce",                        [{"close":[12.59,12.67,12.43,12.35,12.37,12.57,12.48,12.37,12.44,12.42,12.34,12.62,12.71,12.64,12.63,12.94,13.34,13.4,13.56,13.56,13.61,13.37,13.47,13.45,13.19,12.95,13.01,12.85,12.68,12.72,13.0,12.92,12.95,13.02,12.64,12.62,12.64,12.78,12.72,12.64,12.52,12.26,12.06,12.12,12.38,12.64,12.59,12.73,12.6,12.32,12.17,12.05,12.03,11.91,11.7,11.81,11.82,11.36,11.64,11.82,11.71,11.88,11.53,11.75,11.78,11.5,11.38,11.6,11.19,10.73,10.97,11.34,11.38,11.5,11.63,11.78,11.77,11.75,11.75,11.6,11.56,11.47,11.97,11.77,11.45,11.54,11.6,11.55,11.17,11.28,11.16,11.0,10.85,11.23,11.56,11.45,11.45,11.42,11.48,11.75,11.94,12.15,12.13,12.01,12.26,12.01,12.14,12.66,12.64,12.58,12.68,13.22,13.33,13.25,13.34,13.32,13.84,13.7,13.39,13.36,13.28,13.56,13.37,13.31,13.49,13.72,14.01,14.08,14.63,14.13,14.08,13.94,13.76,13.93,13.86,13.68,13.54,13.43,13.55,13.48,13.49,14.12,14.4,14.21,14.15,14.25,13.9,14.27,14.62,14.68,15.12,14.93,14.93,14.54,14.39,14.36,14.05,14.06,14.2,14.08,13.8,13.55,13.65,13.79,13.79,13.48,13.8,13.61,13.58,13.69,13.58,13.23,13.32,13.88
# - Indicadores de volatilidade
# - Indicadores de tendência
# - Indicadores de volume
# - Osciladores

# %% [markdown]
# ## 5.1. Indicadores de Momentum
#
# Momentum é um conceito da física que mede a taxa de aumento ou diminuicação de velocidade de um objeto. Na análise técnica o mesmo conceito é aplicado aos preços buscando entender se uma tendência está em aceleração ou desaceleração.

# %% [markdown]
# ### 5.1.1. Rate of Change

# %%
#Importando da biblioteca TA o indicador

from ta.momentum import ROCIndicator

# %%
#Adicionando o indicador ao dataframe

roc = ROCIndicator(df['Close'])
df['ROC'] = roc.roc()

# %%
#Construindo a figura do gráfico

fig = go.Figure()
    
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='ROC',x=df.index, y=df['ROC']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3',x=df.index, close=df['Close'], open=df['Open'],high=df['High'], low=df['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='ROC BRML3')
fig.show()

# %%
roc2 = ROCIndicator(df2['Close'])
df2['ROC'] = roc2.roc()
df2

# %%
fig = go.Figure()
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='ROC', x=df2.index, y=df2['ROC']), row=2, col=1)
fig.add_trace(go.Candlestick(name='PETR4', x=df2.index, close=df2['Close'], open=df2['Open'], high=df2['High'], low=df2['Low']), row=1, col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='ROC PETR4')
fig.show()

# %% [markdown]
# ### 5.1.2. Percentage Price Oscillator (PPO)
#
# - O PPO é positivo quando a média móvel mais curta está acima da média móvel mais longa. Isso reflete um forte impulso de alta.
# - O PPO é negativo quando a média móvel mais curta está abaixo da média móvel mais longa. As leituras negativas crescem quando a média móvel mais curta se distancia da média móvel mais longa (fica ainda mais negativa).
# - Isso reflete um forte impulso de baixa.
# - O histograma representa a diferença entre o PPO e sua EMA de 9 dias, a linha de sinal.
# - O histograma é positivo quando o PPO está acima de sua EMA de 9 dias e negativo quando o PPO está abaixo de sua EMA de 9 dias.
# - O PPO-Histograma pode ser usado para antecipar cruzamentos de linha de sinal no PPO

# %%
from ta.momentum import PercentagePriceOscillator

# %%
PPO = PercentagePriceOscillator(df['Close'])
df['PPO'] = PPO.ppo()
df['PPO_hist'] = PPO.ppo_hist()
df['PPO_line'] = PPO.ppo_signal()

# %%
fig = make_subplots(rows=2, cols=1, specs =[[{"secondary_y": True}],[{"secondary_y": True}]])
fig.add_trace(go.Scatter(name='PPO', x=df.index, y=df['PPO']), row=2,col=1)
fig.add_trace(go.Bar(name='PPO_hist', x=df.index, y=df['PPO_hist']), row=2, col=1, secondary_y=True)
fig.add_trace(go.Scatter(name='PPO_line', x=df.index, y=df['PPO_line']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high=df['High'], low=df['Low']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='PPO BRML3')
fig.show()

# %%
#Percentage Price Oscillator WEGE3
PPO3 = PercentagePriceOscillator(df3['Close'])
df3['PPO'] = PPO3.ppo()
df3['PPO_hist'] = PPO3.ppo_hist()
df3['PPO_line'] = PPO3.ppo_signal()

# %% [markdown]
# ## 5.2. Osciladores
#
# Osciladores são indicadores que auxiliam a identificar se o ativo está sobrecomprado - força compradora está se esgotando, ou sobrevendido - o oposto da situação anterior onde a força vendedora está enfraquecendo.

# %% [markdown]
# ### 5.2.1. Índice de força relativa (IFR)
#
# <p>
# $ IFR = 100 - {\left(\frac{100}{1 + {\left(\frac{A}{B}\right)}}\right)} $
#
# Onde:<p>
# *A* = média dos preços dos últimos períodos de alta (usualmente fechamento e 14 períodos);<p>
# *B* = média dos preços dos últimos períodos de baixa.<p>

# %%
from ta.momentum import RSIIndicator

# %%
#Inicializando indicador RSI

rsi = RSIIndicator(close=df['Close'],window=30)
df['RSI'] = rsi.rsi()

# %%
#Gráfico Preços/RSI

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='RSI',x=df.index, y=df['RSI']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3',x=df.index, close=df['Close'], open=df['Open'],high=df['High'], low=df['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
#RSI PETR4

rsi2 = RSIIndicator(close=df2['Close'],window=30)
df2['RSI'] = rsi2.rsi()

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='RSI',x=df.index, y=df2['RSI']), row=2, col=1)
fig.add_trace(go.Candlestick(name='PETR4',x=df.index, close=df2['Close'], open=df2['Open'],high=df2['High'], low=df2['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='RSI PETR4')
fig.show()

# %% [markdown]
# ### 5.2.2. Oscilador estocástico

# %%
from ta.momentum import StochasticOscillator

# %%
so = StochasticOscillator(high= df['High'], low= df['Low'],close=df['Close'],window=14)
df['SO'] = so.stoch()

# %%
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='SO',x=df.index, y=df['SO']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3',x=df.index, close=df['Close'], open=df['Open'],high=df['High'], low=df['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
#Oscilador estocastico WEG3

so3 = StochasticOscillator(high= df3['High'], low= df3['Low'],close=df3['Close'],window=14)
df3['SO'] = so3.stoch_signal()

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(name='SO',x=df3.index, y=df3['SO']), row=2, col=1)
fig.add_trace(go.Candlestick(name='WEGE3',x=df3.index, close=df3['Close'], open=df3['Open'],high=df3['High'], low=df3['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='SO WEG3')
fig.show()

# %% [markdown]
# ## 5.3. Indicadores de volatilidade

# %% [markdown]
# ### 5.3.1. Bandas de Bollinger

# %%
from ta.volatility import BollingerBands

# %%
bb = BollingerBands(close=df['Close'], window=20, window_dev=2)
df['bb_bbm'] = bb.bollinger_mavg()
df['bb_bbh'] = bb.bollinger_hband()
df['bb_bbl'] = bb.bollinger_lband()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(name='MédiaMovel', x= df.index, y=df['bb_bbm']))
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high = df['High'], low=df['Low']))
fig.add_trace(go.Scatter(name='Banda Superior', x=df.index, y=df['bb_bbh']))
fig.add_trace(go.Scatter(name='Banda inferior', x=df.index, y=df['bb_bbl']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='Bollinger Bands')
fig.show()

# %%
#BB para PETR4

bb2 = BollingerBands(close=df2['Close'], window=20, window_dev=2)
df2['bb_bbm'] = bb2.bollinger_mavg()
df2['bb_bbh'] = bb2.bollinger_hband()
df2['bb_bbl'] = bb2.bollinger_lband()


fig = go.Figure()
fig.add_trace(go.Scatter(name='MédiaMovel', x= df2.index, y=df2['bb_bbm']))
fig.add_trace(go.Candlestick(name='PETR4', x=df2.index, close=df2['Close'], open=df2['Open'], high = df2['High'], low=df2['Low']))
fig.add_trace(go.Scatter(name='Banda Superior', x=df2.index, y=df2['bb_bbh']))
fig.add_trace(go.Scatter(name='Banda inferior', x=df2.index, y=df2['bb_bbl']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='PETR4 Bollinger Bands')
fig.show()

# %% [markdown]
# ### 5.3.2. ATR - Average True Range

# %%
from ta.volatility import AverageTrueRange

# %%
atr = AverageTrueRange(df['High'], df['Low'], df['Close'])

df['ATR'] = atr.average_true_range()

# %%
fig = make_subplots(rows=2,cols=1)
fig.add_trace(go.Scatter(name='ATR', x=df.index, y=df['ATR']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high = df['High'], low=df['Low']), row=1, col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text = 'ATR')
fig.show()

# %%
#WEGE3 ATR

atr = AverageTrueRange(df3['High'], df3['Low'], df3['Close'])

df3['ATR'] = atr.average_true_range()

fig = make_subplots(rows=2,cols=1)
fig.add_trace(go.Scatter(name='ATR', x=df3.index, y=df3['ATR']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df3['Close'], open=df3['Open'], high = df3['High'], low=df3['Low']), row=1, col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text = 'WEGE3 ATR')
fig.show()

# %% [markdown]
# # 5.4. Indicadores de tendência
#
# Indicadores de tendência buscam captar sinais de um movimento direcional do preço do ativo

# %% [markdown]
# ### 5.4.1. MACD

# %%
from ta.trend import MACD

# %%
macd = MACD(df['Close'])
df['MACD_LINE'] = macd.macd()
df['MACD_DIFF'] = macd.macd_diff()

# %%
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Bar(name='MACD', x=df.index, y=df['MACD_LINE']), row=2,col=1)
fig.add_trace(go.Scatter(name='MACD_DIFF', x=df.index, y=df['MACD_DIFF']), row=2, col=1)
fig.add_trace(go.Scatter(name='MACD_line', x=df.index, y=df['MACD_LINE']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high = df['High'], low=df['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='MACD BRML3')
fig.show()

# %%
macd2 = MACD(df['Close'])
df2['MACD_LINE'] = macd2.macd()
df2['MACD_DIFF'] = macd2.macd_diff()

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Bar(name='MACD', x=df2.index, y=df2['MACD_LINE']), row=2,col=1)
fig.add_trace(go.Scatter(name='MACD_DIFF', x=df2.index, y=df2['MACD_DIFF']), row=2, col=1)
fig.add_trace(go.Scatter(name='MACD_line', x=df2.index, y=df2['MACD_LINE']), row=2, col=1)
fig.add_trace(go.Candlestick(name='BRML3', x=df2.index, close=df2['Close'], open=df2['Open'], high = df2['High'], low=df2['Low']),row=1,col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='MACD WEGE3')
fig.show()

# %% [markdown]
# ### 5.4.2. Simple Moving Average

# %%
from ta.trend import SMAIndicator

# %%
sma_short = SMAIndicator(df['Close'], window=5)
sma_long = SMAIndicator(df['Close'], window=30)
df['SMA_SHORT'] = sma_short.sma_indicator()
df['SMA_LONG'] = sma_long.sma_indicator()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(name='SMA_SHORT', x=df.index, y=df['SMA_SHORT']))
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high = df['High'], low=df['Low']))
fig.add_trace(go.Scatter(name='SMA_LONG', x=df.index, y=df['SMA_LONG']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='Simple Moving Average')
fig.show()

# %% [markdown]
# ### 5.4.3. Média Móvel Exponencial - EMA

# %%
from ta.trend import EMAIndicator

# %%
ema_short = EMAIndicator(df3['Close'], window=5)
ema_long = EMAIndicator(df3['Close'], window=30)
df3['EMA_SHORT'] = ema_short.ema_indicator()
df3['EMA_LONG'] = ema_long.ema_indicator()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(name='EMA_SHORT', x=df3.index, y=df3['EMA_SHORT']))
fig.add_trace(go.Candlestick(name='WEGE3', x=df.index, close=df3['Close'], open=df3['Open'], high = df3['High'], low=df3['Low']))
fig.add_trace(go.Scatter(name='EMA_LONG', x=df3.index, y=df3['EMA_LONG']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='EMA WEGE3')
fig.show()

# %% [markdown]
# ## 5.5. Indicadores de Volume
# Indicadores de volume baseiam-se na quantidade negociada buscando compreender como as forças vendedoras e compradoras influenciam no preço

# %% [markdown]
# ### 5.5.1. OBV - On Balance Volume

# %%
from ta.volume import OnBalanceVolumeIndicator

# %%
obv = OnBalanceVolumeIndicator(df2['Close'], df2['Volume'])
df2['OBV'] = obv.on_balance_volume()

# %%
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Bar(name='OBV', x=df2.index, y=df2['OBV']), row=2, col=1)
fig.add_trace(go.Candlestick(name='PETR4', x=df.index, close=df2['Close'], open=df2['Open'], high=df2['High'], low=df2['Low']), row=1, col=1)
fig.update_layout(xaxis_rangeslider_visible=False, title_text='OBV PETR4')
fig.show()

# %% [markdown]
# ### 5.5.2. VWAP - Volume Weighted Average Price

# %%
from ta.volume import VolumeWeightedAveragePrice

# %%
vwap = VolumeWeightedAveragePrice(df['High'], df['Low'], df['Close'], df['Volume'])
df['VWAP'] = vwap.volume_weighted_average_price()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(name='VWAP', x=df.index, y=df['VWAP']))
fig.add_trace(go.Candlestick(name='BRML3', x=df.index, close=df['Close'], open=df['Open'], high=df['High'], low=df['Low']))
fig.update_layout(xaxis_rangeslider_visible=False, title_text='VWAP')
fig.show()
